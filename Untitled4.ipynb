# %% [markdown]
# <a href="https://colab.research.google.com/github/kalekakenqq/zachet/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ipywidgets as widgets
import os

def get_and_store_secret(placeholder, output_secret_path):
  password_field = widgets.Password(
      description=f"Enter Key:",
      placeholder=placeholder,
      disabled=False
  )

  output = widgets.Output()

  def on_button_click(b):
    with output:
      token = password_field.value
      with open(os.path.expanduser(output_secret_path), "w") as f:
        f.write(token)
      password_field.close()
      button.close()

  button = widgets.Button(description="Save Key")
  button.on_click(on_button_click)

  display(password_field, button, output)
  kaggle_user_path = os.path.expanduser("~/.cache/kaggle-user.txt")
get_and_store_secret("KAGGLE_USERNAME", kaggle_user_path)
kaggle_key_path = os.path.expanduser("~/.cache/kaggle.token")
get_and_store_secret("KAGGLE_KEY", kaggle_key_path)
with open(kaggle_user_path) as f:
    os.environ["KAGGLE_USERNAME"] = f.read().strip()

with open(kaggle_key_path) as f:
    os.environ["KAGGLE_KEY"] = f.read().strip()
# Out:
# Password(description='Enter Key:', placeholder='KAGGLE_USERNAME')
# Button(description='Save Key', style=ButtonStyle())
# Output()
# Password(description='Enter Key:', placeholder='KAGGLE_KEY')
# Button(description='Save Key', style=ButtonStyle())
# Output()

# %%
import pandas as pd          # модуль pandas для работы с данными
from io import StringIO      # модуль для работы с потоками строк в формате CSV

kaggle_datasets_list = !{"kaggle datasets list --csv -p 2"}
kaggle_datasets_list = "\n".join(kaggle_datasets_list)
# Load Data Frame from csv
pd.read_csv(StringIO(kaggle_datasets_list))
# Out:
#                                                   ref  \
# 0               dansbecker/melbourne-housing-snapshot
# 1                               datasnaek/youtube-new
# 2                               zynicide/wine-reviews
# 3                                     datasnaek/chess
# 4                    dansbecker/powerlifting-database
# 5                         residentmario/ramen-ratings
# 6                           jpmiller/publicassistance
# 7                    rtatman/188-million-us-wildfires
# 8                nasa/kepler-exoplanet-search-results
# 9                        nolanbconaway/pitchfork-data
# 10                     residentmario/things-on-reddit
# 11  alperenmyung/social-media-advertisement-perfor...
# 12                wasiqaliyasir/breast-cancer-dataset
# 13    yanghu583/electric-vehicle-population-data-2025
# 14  ludocielbeckett/health-risk-prediction-anonymi...
# 15  aidenl25/air-quality-data-in-brooklyn-ny-opena...
# 16  pratyushpuri/financial-news-market-events-data...
# 17      iabhishekofficial/mobile-price-classification
# 18  mohamadsallah5/english-premier-league-stats202...
# 19   msnbehdani/mock-dataset-of-second-hand-car-sales
#
#                                                 title       size  \
# 0                          Melbourne Housing Snapshot     461423
# 1                   Trending YouTube Video Statistics  210575746
# 2                                        Wine Reviews   53336293
# 3                        Chess Game Dataset (Lichess)    2903760
# 4                               powerlifting-database    9277600
# 5                                       Ramen Ratings      40762
# 6                   US Public Food Assistance 1 - WIC     304041
# 7                           1.88 Million US Wildfires  176270559
# 8                     Kepler Exoplanet Search Results    1215549
# 9                            18,393 Pitchfork Reviews   34891456
# 10                                   Things on Reddit   16773230
# 11             Social Media Advertisement Performance   16190360
# 12                              Breast cancer dataset      49830
# 13              Electric Vehicle Population Data 2025    8281096
# 14      Health Risk Prediction (Anonymized Real Data)      10466
# 15    Air Quality Data in Brooklyn, NY (OpenAQ, 2025)      13316
# 16  Financial News Market Events Dataset for NLP 2025     417736
# 17                        Mobile Price Classification      72340
# 18            English Premier League Stats(2021–2024)      60495
# 19    Car Sales Dataset: Model, Features, and Pricing     501188
#
#                    lastUpdated  downloadCount  voteCount  usabilityRating
# 0   2018-06-05 12:52:24.087000         190680       1666         0.705882
# 1   2019-06-03 00:56:47.177000         282651       5762         0.794118
# 2   2017-11-27 17:08:04.700000         334254       3770         0.794118
# 3   2017-09-04 03:09:09.453000          57875       1387         0.823529
# 4   2019-04-30 21:07:41.560000          22279        307         0.588235
# 5   2018-01-11 16:04:39.893000          52128        952         0.705882
# 6   2023-04-17 20:01:05.960000          23707        487         0.941176
# 7   2020-05-12 21:03:49.213000          39454       1378         0.823529
# 8   2017-10-10 18:26:59.497000          19262        829         0.823529
# 9   2017-01-13 04:18:10.113000          16099        434         0.705882
# 10  2017-10-26 14:10:15.157000          14018        300         0.588235
# 11  2025-08-06 14:27:34.473000           1627         31         1.000000
# 12  2025-07-30 12:52:44.057000          11920        365         1.000000
# 13  2025-08-07 15:16:39.673000           1822         33         1.000000
# 14  2025-08-24 14:51:54.793000           1118         31         1.000000
# 15  2025-08-30 05:31:26.600000            357         21         1.000000
# 16  2025-08-13 21:30:11.640000            743         28         1.000000
# 17  2018-01-28 08:44:24.237000         232532       2383         0.705882
# 18  2025-08-18 14:26:59.597000            935         22         0.705882
# 19  2025-08-20 17:47:58.207000           1057         22         1.000000

# %%
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `unzip -o C:\Users\1132242344\Downloads\archive (4).zip -d'
